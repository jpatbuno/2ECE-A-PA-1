# %% [markdown]
# ## Buño, James Patrick T.

# %% [markdown]
# ## Programming Assignment 1

# %% [markdown]
# ## A. WORD ROTATION PROBLEM

# %%
def rotate_word(text):
 return text[1:] + text[0]

# %%
rotate_word("python")
# Out:
# 'ythonp'

# %%
rotate_word("logic")
# Out:
# 'ogicl'

# %%
rotate_word("Code")
# Out:
# 'odeC'

# %%
rotate_word("A")
# Out:
# 'A'

# %% [markdown]
# ## B. USERNAME BUILDER PROBLEM

# %%
def make_username(first_name, last_name):
    lowercase_first = first_name.lower().replace(" ", "")
    lowercase_last = last_name.lower().replace(" ", "")
    return f"{lowercase_first}.{lowercase_last}"

# %%
make_username("Ada", "Lovelace")
# Out:
# 'ada.lovelace'

# %%
make_username("Alan", "Turing")
# Out:
# 'alan.turing'

# %%
make_username("Ana Maria", "De Leon")
# Out:
# 'anamaria.deleon'

# %% [markdown]
# ## C. BOOKEND SWAP PROBLEM

# %%
def swap_bookends(index):
    first, *middle, last = index
    return [last] + middle + [first]

# %%
swap_bookends([1, 2, 3, 4, 5, 6])
# Out:
# [6, 2, 3, 4, 5, 1]

# %%
swap_bookends(["red", "green", "blue"])
# Out:
# ['blue', 'green', 'red']

# %%
swap_bookends([8, 3])
# Out:
# [3, 8]
